# %% [markdown]
# # Introduction to R, mmm... Python
#
# In this chapter Kruschke introduce the R language. I use the python language, so not everything is relevant.
#
# ## Exercise 1 - Download and install python. Done!
#
# ## Exercise 2 - Record the result of a script
#
# Thankfully, we have jupyter notebook, everythin is self contained: code, text, and outputs (plots / summaries / etc.)

# %% [markdown]
# ## Exercise 3 - Simple plotting

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn  # Just for styles

# %matplotlib inline

# %%
x = np.linspace(-3, 3, 100)
y = x ** 3

plt.plot(x, y)
plt.xlabel('$x$')
plt.ylabel('$y = x ^ 3$')
plt.title('Qubic function');
